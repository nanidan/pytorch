# %% [markdown]
# # 线性回归的基础实现逻辑

# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

# %%
# 生成数据集
def synthetic_data(w, b, num_examples):
    """生成y = Xw + b + 噪声"""
    X = torch.normal(0, 1, (num_examples, len(w)))
    
    y = torch.matmul(X, w) + b
    y += torch.normal(0, 0.01, y.shape)
    return X, y.reshape((-1, 1))

true_w = torch.tensor([2, -3.4])
true_b = 4.2
features, labels = synthetic_data(true_w, true_b, 1000)

# %%
print('features:', features[0], '\nlabel:', labels[0])
# Out:
# features: tensor([-0.6752,  0.7777])
# label: tensor([0.2044])

# %%
d2l.set_figsize()
d2l.plt.scatter(features[:, (1)].detach().numpy(),
                labels.detach().numpy(), 1);

# %% [markdown]
# ## 读取数据集

# %%
def data_iter(batch_size, features, labels):
    #读取特征的长度
    num_examples = len(features)
    indices = list(range(num_examples))
    
    #定一个一个随机读取的规则
    random.shuffle(indices)
    
    for i in range(0, num_examples, batch_size):
        batch_indices = torch.tensor(indices[i:min(i + batch_size, num_examples)]) #每次取一定batch_size的数据
        
        yield features[batch_indices], labels[batch_indices]   #batch_indices 是下标的list，然后去特征里面取相应的值

# %%
batch_size = 10

for X, y in data_iter(batch_size, features, labels):
    print(X, '\n',y)
    break
# Out:
# tensor([[ 2.8305e-01,  6.9546e-01],
#         [ 1.6873e+00,  9.5392e-01],
#         [-1.4163e+00,  8.9237e-01],
#         [-9.1772e-01,  1.2486e-03],
#         [ 2.5389e-01, -1.4207e+00],
#         [-3.7438e-01,  1.0500e-01],
#         [-1.7486e+00, -1.0163e+00],
#         [-9.0161e-01, -5.1879e-01],
#         [ 1.3414e+00,  1.5267e+00],
#         [ 7.2884e-01, -1.0162e+00]])
#  tensor([[ 2.4028],
#         [ 4.3237],
#         [-1.6652],
#         [ 2.3749],
#         [ 9.5432],
#         [ 3.1000],
#         [ 4.1720],
#         [ 4.1484],
#         [ 1.6897],
#         [ 9.1276]])

# %% [markdown]
# # 初始化模型参数

# %%
w = torch.normal(0,0.01, size=(2,1), requires_grad=True)  #要求求梯度
b = torch.zeros(1, requires_grad=True)

# %%
#定义模型
def linreg(X, w, b):
    return torch.matmul(X, w) + b

#定义损失函数,均方损失

def squared_loss(y_hat, y):
    
    return(y_hat - y.reshape(y_hat.shape))**2/2


#定义一个优化算法,小批量随机梯度算法
def sgd(params, lr, batch_size):
    with torch.no_grad():
        for param in params:
            param -= lr * param.grad / batch_size
            param.grad.zero_()

# %%
#训练
lr = 0.03
num_epochs = 3
net = linreg
loss = squared_loss

for epoch in range(num_epochs):
    for X, y in data_iter(batch_size, features, labels):
        l = loss(net(X, w, b), y)  #X和y的小批量损失
        
        l.sum().backward()
        sgd([w,b], lr, batch_size)
    with torch.no_grad():
        train_l = loss(net(features, w, b), labels)
        print(f'epoch{epoch + 1}, loss{float(train_l.mean()):f}')
# Out:
# epoch1, loss0.000050
# epoch2, loss0.000050
# epoch3, loss0.000051

# %%
print(f'w的估计误差: {true_w - w.reshape(true_w.shape)}')
print(f'b的估计误差: {true_b - b}')
# Out:
# w的估计误差: tensor([ 6.4969e-05, -2.1267e-04], grad_fn=<SubBackward0>)
# b的估计误差: tensor([0.0003], grad_fn=<RsubBackward1>)

# %%
true_w
# Out:
# tensor([ 2.0000, -3.4000])

# %%
b
# Out:
# tensor([4.1997], requires_grad=True)
